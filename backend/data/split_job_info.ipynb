# %%
import numpy as np
import pandas as pd
df_info_job = pd.read_csv("rag_job_tables/job_info_original.csv")

# %%
chuck_size = 1000
for i in range(0, len(df_info_job), chuck_size):
    df_info_job[i: i + chuck_size].to_csv(f'job_data_part_{i//chuck_size + 1}.csv', index=False)
